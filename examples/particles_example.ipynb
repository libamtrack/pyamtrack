# %%
import pyamtrack.particles as p

# %% [markdown]
# -----------
# Particle constructor

# %%
p.Particle(11)
# Out:
# Particle(name="electron", acronym="e")

# %%
p.Particle(2212)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 p.Particle(2212)
#
# ValueError: Use particles.ions.Ion() constructor for PDG codes corresponding to ions

# %% [markdown]
# ------------
# Ion constructor

# %%
p.ions.Ion(2212)
# Out:
# Ion(element_name="Hydrogen", element_acronym="H", Z=1, A=1)

# %%
p.ions.Ion(11)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 p.ions.Ion(11)
#
# ValueError: Use particles.Particle() constructor for PDG codes corresponding to non-ions

# %% [markdown]
# --------------
# from pdg method

# %%
p.from_pdg(11)
# Out:
# Particle(name="electron", acronym="e")

# %%
p.from_pdg(2212)
# Out:
# Ion(element_name="Hydrogen", element_acronym="H", Z=1, A=1)

# %% [markdown]
# -------------------------
# particle module attributes

# %%
p.C
# Out:
# Ion(element_name="Carbon", element_acronym="C", Z=6, A=12)

# %%
p.proton
# Out:
# Ion(element_name="Hydrogen", element_acronym="H", Z=1, A=1)

# %% [markdown]
# ------------
# from string method

# %%
p.from_string("C")
# Out:
# Ion(element_name="Carbon", element_acronym="C", Z=6, A=12)

# %%
p.from_string("electron")
# Out:
# Particle(name="electron", acronym="e")

# %%
p.from_string("proton")
# Out:
# Ion(element_name="Hydrogen", element_acronym="H", Z=1, A=1)

# %%
p.from_string("C-12")
# Out:
# Ion(element_name="Carbon", element_acronym="C", Z=6, A=12)

# %%
p.from_string("12-C")
# Out:
# Ion(element_name="Carbon", element_acronym="C", Z=6, A=12)

# %%
p.from_string("C_14")
# Out:
# Ion(element_name="Carbon", element_acronym="C", Z=6, A=14)

# %%
p.from_string("C_15")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 p.from_string("C_15")
#
# ValueError: Invalid mass number A=15 for element C (valid range: 12-14)

# %% [markdown]
# ----------------
# from ZA method

# %%
p.from_ZA(1,1)
# Out:
# Ion(element_name="Hydrogen", element_acronym="H", Z=1, A=1)

# %%
p.from_ZA(Z=6, A=13)
# Out:
# Ion(element_name="Carbon", element_acronym="C", Z=6, A=13)

# %%
p.from_ZA(A=14, Z=6)
# Out:
# Ion(element_name="Carbon", element_acronym="C", Z=6, A=14)

# %%
p.from_ZA(6,13)
# Out:
# Ion(element_name="Carbon", element_acronym="C", Z=6, A=13)

# %%
p.from_ZA(6,10)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 p.from_ZA(6,10)
#
# ValueError: Invalid mass number A=10 for element C (valid range: 12-14)
