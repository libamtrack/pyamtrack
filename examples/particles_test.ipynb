# %%
import pyamtrack.particles as p

# %%
p.Particle(11)
# Out:
# [Particle electron (id=-1)]

# %%
p.ions.Ion(2212)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 p.ions.Ion(2212)
#
# ValueError: Use particles.ions.Ion() constructor for PDG codes corresponding to ions

# %%
p.Particle(11)
# Out:
# [Particle electron (id=-1)]
