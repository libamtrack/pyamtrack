# %%
import pyamtrack.particles as p

# %%
p.Particle(11)
# Out:
# [Particle electron)]

# %%
p.ions.Ion(2212)
# Out:
# [Ion Hydrogen (Z=1, A=1)]

# %%
p.Particle(2212)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 p.Particle(2212)
#
# ValueError: Use particles.ions.Ion() constructor for PDG codes corresponding to ions

# %%
p.ions.Ion(11)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 p.ions.Ion(11)
#
# ValueError: Use particles.Particle() constructor for PDG codes corresponding to non-ions
